# %%
import pandas as pd
import xml.etree.ElementTree as ET
import ast

# %%
with open('data/0.xml', 'r') as f:
    data=f.read()

# %%
data_dict = ast.literal_eval(data)

# %%
data_dict

# %%
def extract_data(xml_string):
    data_dict = {}
    # Parse XML string
    xml_parsed = ET.fromstring(xml_string)
    # Extract data from XML
    for elem in xml_parsed:
        data_dict[elem.tag] = elem.text
    return data_dict

# %%
data = pd.read_json('data/0.json')

# %%
data = pd.read_json("data/0.json")
data = data.transpose()
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
import os

full_df = pd.DataFrame()
for filename in os.listdir("data/"):
    # Check if the entry is a file
    if os.path.isfile(os.path.join("data/", filename)):
        df = pd.read_json(os.path.join("data/", filename))
        df = df.transpose()
        full_df = pd.concat([full_df, df])

full_df
# Out:
#       articles_count                                            authors  \
# 2                106                           [Li, X.S., Demmel, J.W.]
# 3                  1                                     [Bobkov, V.F.]
# 4                  9   [R. Ramis, J. Meyer-ter-Vehn, J. Ram&iacute;rez]
# 5                127                                   [Pozrikidis, C.]
# 6                 37                             [Engelman, Michael S.]
# ...              ...                                                ...
# 10283              2  [Scott, N.S., Scott, M.P., Burke, P.G., Stitt,...
# 10284              3     [Bogacz, L., Burda, Z., Janke, W., Waclaw, B.]
# 10285              2                                 [Bunge, Carlos F.]
# 10286              1                                 [Daniluk, Andrzej]
# 10287              1                                 [Daniluk, Andrzej]
#
#                                           classification dependencies  \
# 2      [35, 65, 68, 74, 76, 05, 15, 60, 78, 80, 81, 8...         None
# 3                                               [65, 76]         None
# 4                                   [35, 65, 76, 78, 80]         None
# 5      [35, 65, 74, 76, 92, 37, 41, 45, 49, 68, 70, 7...        FDLIB
# 6                       [35, 65, 76, 80, 92, 74, 82, 86]         None
# ...                                                  ...          ...
# 10283                                               [81]         None
# 10284                                   [00, 05, 15, 90]         None
# 10285                                       [65, 81, 82]         None
# 10286                                           [68, 81]         None
# 10287                                           [68, 81]         None
#
#                                              description  \
# 2      zbMATH Open Web Interface contents unavailable...
# 3      zbMATH Open Web Interface contents unavailable...
# 4      zbMATH Open Web Interface contents unavailable...
# 5      zbMATH Open Web Interface contents unavailable...
# 6      zbMATH Open Web Interface contents unavailable...
# ...                                                  ...
# 10283  zbMATH Open Web Interface contents unavailable...
# 10284  zbMATH Open Web Interface contents unavailable...
# 10285  zbMATH Open Web Interface contents unavailable...
# 10286  zbMATH Open Web Interface contents unavailable...
# 10287  zbMATH Open Web Interface contents unavailable...
#
#                                                 homepage     id  \
# 2             http://crd-legacy.lbl.gov/~xiaoye/SuperLU/      2
# 3      http://www.mathnet.ru/php/archive.phtml?wshow=...      3
# 4       http://cpc.cs.qub.ac.uk/summaries/AECV_v1_0.html      4
# 5                    http://dehesa.freeshell.org/BEMLIB/      5
# 6      http://www.sciencedirect.com/science/article/p...      6
# ...                                                  ...    ...
# 10283  http://www.cpc.cs.qub.ac.uk/summaries/AEEA_v1_...  10283
# 10284  http://www.cpc.cs.qub.ac.uk/summaries/ADWL_v1_...  10284
# 10285  http://www.cpc.cs.qub.ac.uk/summaries/ADOP_v1_...  10285
# 10286  http://www.cpc.cs.qub.ac.uk/summaries/ADVL_v2_...  10286
# 10287  http://www.cpc.cs.qub.ac.uk/summaries/ADVL_v2_...  10287
#
#                                                 keywords license_terms  \
# 2                                                 [orms]          None
# 3      [numerical methods, mesh generation and refine...          None
# 4      [Inertial Confinement, Radiative Transfer, Lag...          None
# 5      [boundary element method, textbook, Green's fu...          None
# 6      [steady state or transient, two-dimensional, a...          None
# ...                                                  ...           ...
# 10283  [atomic collision processes, electron impact e...          None
# 10284  [random graphs, complex networks, Markov proce...          None
# 10285  [numerical examples, benchmark, eigenproblem, ...          None
# 10286  [reflection high-energy electron diffraction (...          None
# 10287  [reflection high-energy electron diffraction (...          None
#
#                name operating_systems orms_id programming_languages  \
# 2      SuperLU-DIST              None     265                  None
# 3           WHISPAR              None    None                  None
# 4           MULTI2D       Linux/Unix.    None                    C.
# 5            BEMLIB              None    None                  None
# 6             FIDAP              None    None                  None
# ...             ...               ...     ...                   ...
# 10283         2DRMP              None    None                  None
# 10284      GraphGen              None    None                  None
# 10285        HQRII1              None    None                  None
# 10286      GROWTHgr              None    None                  None
# 10287      GROWTH06              None    None                  None
#
#                                         related_software source_code  \
# 2      [{'id': 4013, 'name': 'MUMPS'}, {'id': 4012, '...        None
# 3                                                     []        None
# 4      [{'id': 9029, 'name': 'CHIC'}, {'id': 3107, 'n...        None
# 5      [{'id': 1160, 'name': 'SERBA'}, {'id': 22960, ...        None
# 6      [{'id': 7692, 'name': 'SPARSKIT'}, {'id': 4031...        None
# ...                                                  ...         ...
# 10283  [{'id': 10282, 'name': 'FARM_2DRMP'}, {'id': 1...        None
# 10284  [{'id': 4082, 'name': 'CPLEX'}, {'id': 29134, ...        None
# 10285  [{'id': 545, 'name': 'Maple'}, {'id': 7743, 'n...        None
# 10286                [{'id': 10287, 'name': 'GROWTH06'}]        None
# 10287                [{'id': 10286, 'name': 'GROWTHgr'}]        None
#
#                                        standard_articles  \
# 2      [{'authors': [], 'id': 2187846, 'source': 'zbM...
# 3                                                     []
# 4      [{'authors': [], 'id': 5812948, 'source': 'zbM...
# 5      [{'authors': [], 'id': 1852568, 'source': 'zbM...
# 6      [{'authors': [], 'id': 3775087, 'source': 'zbM...
# ...                                                  ...
# 10283                                                 []
# 10284                                                 []
# 10285                                                 []
# 10286                                                 []
# 10287                                                 []
#
#                               zbmath_url
# 2          https://zbmath.org/software/2
# 3          https://zbmath.org/software/3
# 4          https://zbmath.org/software/4
# 5          https://zbmath.org/software/5
# 6          https://zbmath.org/software/6
# ...                                  ...
# 10283  https://zbmath.org/software/10283
# 10284  https://zbmath.org/software/10284
# 10285  https://zbmath.org/software/10285
# 10286  https://zbmath.org/software/10286
# 10287  https://zbmath.org/software/10287
#
# [46210 rows x 17 columns]

# %%
full_df.reset_index(drop=True, inplace=True)
full_df.to_json("data/full_data.json", orient='columns')
